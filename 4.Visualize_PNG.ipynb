# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_image(img,blue,green,red):
    
    images = [img,blue,green,red]
    title = ['Original','Brain','Subdural','Soft']
    
    fig=plt.figure(figsize=(10, 10))
    
    columns = 2
    rows = 2
    
    for i in range(1, columns*rows+1):
        fig.add_subplot(rows, columns, i)
        plt.imshow(images[i-1],cmap='gray')
        plt.title(title[i-1])
        
    plt.show()

# %%
img = cv.imread('1.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
blue, green, red = cv.split(img)
show_image(img,blue,green,red)

# %%
img = cv.imread('2.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
blue, green, red = cv.split(img)
show_image(img,blue,green,red)

# %%
img = cv.imread('3.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
blue, green, red = cv.split(img)
show_image(img,blue,green,red)

# %%
img = cv.imread('4.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
blue, green, red = cv.split(img)
show_image(img,blue,green,red)
